# %%
num = [2,3,4,5]
num.split()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 num = [2,3,4,5]
# ----> 2 num.split()
#
# AttributeError: 'list' object has no attribute 'split'

# %%
22//3
# Out:
# 7

# %%
22/3
# Out:
# 7.333333333333333

# %%
name = 'Udyaditya Deo'

# %%
name.index('U')
# Out:
# 0

# %%
str = ['uday', 'deo']
str[1][2]
# Out:
# 'o'

# %%
str.

# %%
class Solution(object):
    def longestCommonPrefix(self, strs):
        """
        :type strs: List[str]
        :rtype: str
        """
        strs = ['aaa', 'abaa', 'aaab']
        common= ''
        for i in strs:
            for j in range(len(i)):
                if i.index(j) == (strs[strs.index(i)+1]).index(j):
                    common += + i.index(j)
        return common

# %%
def is_valid_parentheses(s):
    stack = []
    mapping = {')': '(', ']': '[', '}': '{'}
    for char in s:
        if char in mapping.values():
            stack.append(char)
        elif char in mapping:
            if not stack or stack.pop() != mapping[char]:
                return False
    return not stack
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 name.followers().index('U')
#
# AttributeError: 'str' object has no attribute 'followers'

# %%
num =[2,2,2,3,3,4,5]

# %%
num.remove(2)
num
# Out:
# [2, 3, 3, 4]

# %%
class Solution(object):
    def removeDuplicates(self, nums):
        """
        :type nums: List[int]
        :rtype: int
        """
        i = 0
        while i < len(nums)-1:
            if nums[i] == nums[i+1]:
                nums.remove(i+1)
            else:
                i += 1
            return nums

# %%
class Solution:
    def removeDuplicates(self, nums):
        if not nums:
            return 0
        i = 0
        while i < len(nums) - 1:
            if nums[i] == nums[i + 1]:
                nums.pop(i + 1)
            else:
                i += 1
        return len(nums)

# %%
result = Solution().removeDuplicates([1,1,2,2,3,4,4,5])
print(result)
# Out:
# 5

# %%
class Solution(object):
    def searchInsert(self, nums, target):
        """
        :type nums: List[int]
        :type target: int
        :rtype: int
        """
        if not nums:
            return 0
        i = 0
        while i < len(nums) - 1:
            if nums[i] == target:
                return i

            if nums[i] > target:
                return i-1
            i += 1
        return i + 1 if nums[-1] < target else i

# %%
def strStr():
