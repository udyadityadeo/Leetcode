# %%
num = [2,3,4,5]
num.split()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 num = [2,3,4,5]
# ----> 2 num.split()
#
# AttributeError: 'list' object has no attribute 'split'

# %%
22//3
# Out:
# 7

# %%
22/3
# Out:
# 7.333333333333333
